# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\Python course\10\data.csv")
df
# Out:
#    invoice_no customer_id  gender  age         category  quantity    price  \
# 0     I138884     C241288  Female   28         Clothing         5  1500.40
# 1     I317333     C111565    Male   21            Shoes         3  1800.51
# 2     I127801     C266599    Male   20         Clothing         1   300.08
# 3     I173702     C988172  Female   66            Shoes         5  3000.85
# 4     I337046     C189076  Female   53            Books         4    60.60
# 5     I227836     C657758  Female   28         Clothing         5  1500.40
# 6     I121056     C151197  Female   49        Cosmetics         1    40.66
# 7     I293112     C176086  Female   32         Clothing         2   600.16
# 8     I293455     C159642    Male   69         Clothing         3   900.24
# 9     I326945     C283361  Female   60         Clothing         2   600.16
# 10    I306368     C240286  Female   36  Food & Beverage         2    10.46
# ...

# %%
df[:11]
# Out:
#    invoice_no customer_id  gender  age         category  quantity    price  \
# 0     I138884     C241288  Female   28         Clothing         5  1500.40
# 1     I317333     C111565    Male   21            Shoes         3  1800.51
# 2     I127801     C266599    Male   20         Clothing         1   300.08
# 3     I173702     C988172  Female   66            Shoes         5  3000.85
# 4     I337046     C189076  Female   53            Books         4    60.60
# 5     I227836     C657758  Female   28         Clothing         5  1500.40
# 6     I121056     C151197  Female   49        Cosmetics         1    40.66
# 7     I293112     C176086  Female   32         Clothing         2   600.16
# 8     I293455     C159642    Male   69         Clothing         3   900.24
# 9     I326945     C283361  Female   60         Clothing         2   600.16
# 10    I306368     C240286  Female   36  Food & Beverage         2    10.46
#
#    payment_method invoice_date     shopping_mall
# ...

# %%
df[48:]
# Out:
#    invoice_no customer_id  gender  age         category  quantity    price  \
# 48    I269690     C126436    Male   18        Cosmetics         3   121.98
# 49    I304265     C653385  Female   22            Books         5    75.75
# 50    I246562     C227070  Female   61        Cosmetics         5   203.30
# 51    I202367     C317478  Female   41            Books         3    45.45
# 52    I664787     C237330  Female   53        Cosmetics         2    81.32
# 53    I160777     C626042  Female   43       Technology         4  4200.00
# 54    I137794     C133687  Female   45  Food & Beverage         3    15.69
# 55    I148377     C841663  Female   29         Clothing         1   300.08
# 56    I258195     C213742    Male   43             Toys         2    71.68
# 57    I300213     C962515  Female   19         Clothing         4  1200.32
# 58    I263803     C112279  Female   67  Food & Beverage         3    15.69
#
#    payment_method invoice_date      shopping_mall
# ...

# %%
df.columns.to_list()
# Out:
# ['invoice_no',
#  'customer_id',
#  'gender',
#  'age',
#  'category',
#  'quantity',
#  'price',
#  'payment_method',
#  'invoice_date',
#  'shopping_mall']

# %%
len(df)
# Out:
# 59

# %%
df.info()                   #5
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      59 non-null     object
#  1   customer_id     59 non-null     object
#  2   gender          59 non-null     object
#  3   age             59 non-null     int64
#  4   category        59 non-null     object
#  5   quantity        59 non-null     int64
#  6   price           59 non-null     float64
#  7   payment_method  59 non-null     object
#  8   invoice_date    59 non-null     object
#  9   shopping_mall   59 non-null     object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 4.7+ KB

# %%
df.describe()
# Out:
#              age   quantity        price
# count  59.000000  59.000000    59.000000
# mean   43.033898   3.000000   800.978136
# std    16.131962   1.339068  1107.037109
# min    18.000000   1.000000     5.230000
# 25%    28.000000   2.000000    75.750000
# 50%    43.000000   3.000000   300.080000
# 75%    53.500000   4.000000  1200.320000
# max    69.000000   5.000000  5250.000000

# %%
df.columns[4]
# Out:
# 'category'

# %%
df[data.columns[4]]
# Out:
# 0            Clothing
# 1               Shoes
# 2            Clothing
# 3               Shoes
# 4               Books
# 5            Clothing
# 6           Cosmetics
# 7            Clothing
# 8            Clothing
# 9            Clothing
# 10    Food & Beverage
# 11              Books
# 12               Toys
# 13           Clothing
# 14           Clothing
# 15              Shoes
# 16              Books
# 17    Food & Beverage
# 18           Clothing
# 19               Toys
# 20           Clothing
# 21    Food & Beverage
# 22           Clothing
# 23         Technology
# 24              Books
# 25               Toys
# 26          Cosmetics
# 27              Shoes
# 28              Shoes
# 29          Cosmetics
# 30               Toys
# 31           Clothing
# 32              Shoes
# 33           Clothing
# 34              Shoes
# 35    Food & Beverage
# 36           Clothing
# 37           Clothing
# 38           Clothing
# 39           Clothing
# 40    Food & Beverage
# ...

# %%
df["age"].median()
# Out:
# 43.0

# %%
df["age"].max()
# Out:
# 69

# %%
df["age"].min()
# Out:
# 18

# %%
df[df["quantity"]>3] ["invoice_no"] #9
# Out:
# 0     I138884
# 3     I173702
# 4     I337046
# 5     I227836
# 12    I640508
# 15    I688768
# 19    I992454
# 23    I252275
# 24    I174250
# 26    I196704
# 27    I217053
# 33    I109053
# 34    I167211
# 36    I147062
# 43    I826174
# 45    I117291
# 47    I205366
# 49    I304265
# 50    I246562
# 53    I160777
# 57    I300213
# Name: invoice_no, dtype: object

# %%
df.isna().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
df.grouby[["quantity"],["category"]] # مش عارفة احلها(11

# %%
import numpy as np

# %%
df.pivot(index='category', columns='payment method', aggfunc=np.sum)  #####################
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df.pivot(index='category', columns='payment method', aggfunc=np.sum)
#
# TypeError: DataFrame.pivot() got an unexpected keyword argument 'aggfunc'

# %%
pd.crosstab(df.invoice_no, df.shopping_mall)
# Out:
# shopping_mall  Cevahir AVM  Emaar Square Mall  Forum Istanbul  Istinye Park  \
# invoice_no
# I106674                  0                  0               0             0
# I109053                  0                  0               0             0
# I117291                  0                  0               0             0
# I121056                  0                  0               0             1
# I127801                  0                  0               0             0
# I137794                  0                  0               0             0
# I138674                  0                  0               0             0
# I138884                  0                  0               0             0
# I139207                  0                  1               0             0
# I147062                  0                  0               0             0
# I148377                  0                  0               0             1
# ...
